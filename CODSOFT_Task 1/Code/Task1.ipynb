# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings(action='ignore',category=Warning)

# %%
df=pd.read_csv("../Data/Titanic-Dataset.csv")
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df["Survived"]=df["Survived"].map({0:"No",1:"Yes"})

# %%
df["Survived"].value_counts()
# Out:
# Survived
# No     549
# Yes    342
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,6))
plt.title("Survival Distribution : Bar chart")
sns.countplot(x="Survived",data=df,palette="viridis")
plt.xlabel("Survival Status")
plt.ylabel("Count")
plt.show();

# %%
plt.figure(figsize=(6, 6))
plt.title("Pclass Distribution")
df["Pclass"].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=sns.color_palette('viridis'))
plt.axis('equal')
plt.show()

# %%
df.drop(["Name","PassengerId"],axis=1,inplace=True)

# %%
plt.figure(figsize=(6,6))
sns.countplot(x="Pclass",hue="Survived",data=df,palette="viridis")
plt.title("People Survived in each class")
plt.xlabel("Pclass")
plt.ylabel("Count")
plt.legend(title="Survived Status",loc="upper right",labels=["No","Yes"])
plt.show();

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    object
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Ticket    891 non-null    object
#  7   Fare      891 non-null    float64
#  8   Cabin     204 non-null    object
#  9   Embarked  889 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 69.7+ KB

# %%
plt.figure(figsize=(6,6))
plt.title("Sex Distribution : Bar chart")
sns.countplot(x="Sex",data=df,palette="viridis")
plt.xlabel("Sex")
plt.ylabel("Count")
plt.show();

# %%
plt.figure(figsize=(6,6))
sns.countplot(x="Sex",hue="Survived",data=df,palette="viridis")
plt.title("Male/Female Survived")
plt.xlabel("Sex")
plt.ylabel("Count")
plt.legend(title="Survived Status",loc="upper right",labels=["No","Yes"])
plt.show();

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    object
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Ticket    891 non-null    object
#  7   Fare      891 non-null    float64
#  8   Cabin     204 non-null    object
#  9   Embarked  889 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 69.7+ KB

# %%
df["SibSp"].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8], dtype=int64)

# %%
df.drop(["Ticket"],axis=1,inplace=True)

# %%
df["Age"].hist()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20,10))
g=sns.FacetGrid(df,col="Survived",margin_titles=True)
g.map(plt.hist,"Age",bins=20,color="steelblue",lw=0)
g.set_axis_labels("Age","Count")
plt.show();

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    object
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Cabin     204 non-null    object
#  8   Embarked  889 non-null    object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 62.8+ KB

# %%
df.Parch.value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
df["Cabin"]=~df["Cabin"].isna()
df.head()
# Out:
#   Survived  Pclass     Sex   Age  SibSp  Parch     Fare  Cabin Embarked
# 0       No       3    male  22.0      1      0   7.2500  False        S
# 1      Yes       1  female  38.0      1      0  71.2833   True        C
# 2      Yes       3  female  26.0      0      0   7.9250  False        S
# 3      Yes       1  female  35.0      1      0  53.1000   True        S
# 4       No       3    male  35.0      0      0   8.0500  False        S

# %%
plt.figure(figsize=(6,6))
sns.countplot(x="Cabin",hue="Survived",data=df,palette="viridis")
plt.title("People Survived in each cabin")
plt.xlabel("Cabin")
plt.ylabel("Count")
plt.legend(title="Survived Status",loc="upper right",labels=["No","Yes"])
plt.show();

# %% [markdown]
# Cabin was good for survival status

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    object
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Cabin     891 non-null    bool
#  8   Embarked  889 non-null    object
# dtypes: bool(1), float64(2), int64(3), object(3)
# memory usage: 56.7+ KB

# %%
plt.figure(figsize=(6,6))
sns.countplot(x="Embarked",hue="Survived",data=df,palette="viridis")
plt.title("People Survived as per port")
plt.xlabel("port")
plt.ylabel("Count")
plt.legend(title="Survived Status",loc="upper right",labels=["No","Yes"])
plt.show();

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    object
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Cabin     891 non-null    bool
#  8   Embarked  889 non-null    object
# dtypes: bool(1), float64(2), int64(3), object(3)
# memory usage: 56.7+ KB

# %%
df["Age"].fillna(df["Age"].mean(),inplace=True)

# %%
df['Embarked']=df["Embarked"].astype("str")
df['Embarked'] = df['Embarked'].str.strip()

# %%
df.head()
# Out:
#   Survived  Pclass     Sex   Age  SibSp  Parch     Fare  Cabin Embarked
# 0       No       3    male  22.0      1      0   7.2500  False        S
# 1      Yes       1  female  38.0      1      0  71.2833   True        C
# 2      Yes       3  female  26.0      0      0   7.9250  False        S
# 3      Yes       1  female  35.0      1      0  53.1000   True        S
# 4       No       3    male  35.0      0      0   8.0500  False        S

# %%
df["Embarked"]=df['Embarked'].map({"S":0,"C":1,"Q":2,"nan":0})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    object
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Cabin     891 non-null    bool
#  8   Embarked  891 non-null    int64
# dtypes: bool(1), float64(2), int64(4), object(2)
# memory usage: 56.7+ KB

# %%
df["Sex"]=df["Sex"].map({"male": 0,"female":1})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    object
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    int64
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Cabin     891 non-null    bool
#  8   Embarked  891 non-null    int64
# dtypes: bool(1), float64(2), int64(5), object(1)
# memory usage: 56.7+ KB

# %%
df.head()
# Out:
#   Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Cabin  Embarked
# 0       No       3    0  22.0      1      0   7.2500  False         0
# 1      Yes       1    1  38.0      1      0  71.2833   True         1
# 2      Yes       3    1  26.0      0      0   7.9250  False         0
# 3      Yes       1    1  35.0      1      0  53.1000   True         0
# 4       No       3    0  35.0      0      0   8.0500  False         0

# %%
df["Survived"]=df["Survived"].map({'No':0,'Yes':1})
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
correlation_matrix = df.corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
X=df.drop("Survived",axis=1)
y=df["Survived"]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=9)

# %%
clf=RandomForestClassifier(n_estimators=300)
clf.fit(X_train,y_train)
clf.score(X_train,y_train)
# Out:
# 0.9895209580838323

# %%
clf.score(X_test,y_test)
# Out:
# 0.7892376681614349

# %%
from sklearn.metrics import classification_report,confusion_matrix,ConfusionMatrixDisplay
def evaluate_model(model, X_test, y_test):
    model_name = type(model).__name__
    # Predictions on test set
    y_pred = model.predict(X_test)

    print(f"Classification Report for {model_name}:\n")
    print(classification_report(y_test, y_pred))

    cm = confusion_matrix(y_test, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
    disp.plot(values_format='d')
    plt.title(f'Confusion Matrix - {model_name}')
    plt.show()

# %%
evaluate_model(clf,X_test,y_test)
# Out:
# Classification Report for RandomForestClassifier:
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.86      0.83       130
#            1       0.78      0.69      0.73        93
#
#     accuracy                           0.79       223
#    macro avg       0.79      0.77      0.78       223
# weighted avg       0.79      0.79      0.79       223
